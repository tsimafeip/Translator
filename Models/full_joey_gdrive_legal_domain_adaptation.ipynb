# %%
import os

if not os.path.isdir("/content/Separate Corpuses/FullCorpus/") or not os.path.isdir("/joey_experiments/"):
    # !gsutil -m cp -r "gs://mytranslator-298419-vcm/joeynmt/" .

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Configuring model parameters.
source_language = "ru"
target_language = "be"
lang_pair = source_language+target_language
tag = "legal"
config_name = "legal_data_config.yaml"

use_cuda = True
first_run = True

gdrive_path = "/content/drive/My Drive/joey_experiments/%s-%s-%s" % (source_language, target_language, tag)

raw_source_file = r"/content/drive/My Drive/TranslatorData/LegalData/legal_data_train_ru.txt"
raw_target_file = r"/content/drive/My Drive/TranslatorData/LegalData/legal_data_train_be.txt"

raw_source_test_file = r"/content/drive/My Drive/TranslatorData/LegalData/legal_data_test_ru.txt"
raw_target_test_file = r"/content/drive/My Drive/TranslatorData/LegalData/legal_data_test_be.txt"

# %%
# Setting helper parameters. Do not change it.
from os import path

os.environ["gdrive_path"] = gdrive_path
! echo $gdrive_path
! mkdir -p "$gdrive_path"

# Sets params in bash as well, since we often use bash scripts.
os.environ["data_path"] = path.join("joeynmt", "data", source_language + target_language)
os.environ["bpe_codes_file"] = path.join(gdrive_path, "data", "bpe.codes.5000")
os.environ["src"] = source_language 
os.environ["tgt"] = target_language
os.environ["lang_pair"] = lang_pair
os.environ["tag"] = tag
os.environ["config_name"] = config_name
# Out:
# /content/drive/My Drive/joey_experiments/ru-be-legal

# %%
# %%capture
! pip install -Iv sacremoses==0.0.40
! pip install -Iv six==1.12.0

# %%
def preprocess(filepath, language, force_preprocess=False, pretrained_tc_model=None):
    tok_file = filepath+"_tok.txt"
    tc_model = pretrained_tc_model if pretrained_tc_model else filepath+"_tc.model"
    truecased_file = tok_file+"_true.txt"

    if force_preprocess:
      ! sed -i 's/"//g' "$filepath"
      ! sacremoses tokenize -l language -e 'utf-8' < "$filepath" > "$tok_file"
      if not pretrained_tc_model:
        ! sacremoses train-truecase -m "$tc_model" -j 4 < "$tok_file"
      ! echo "$tc_model"
      ! sacremoses truecase -m "$tc_model" -j 4 < "$tok_file" > "$truecased_file"

    return truecased_file, tc_model

# Change the pointers to our files such that we continue to work with the tokenized and truecased data.
force_preprocess = True if first_run else False

source_file, source_tc_model = preprocess(raw_source_file, source_language, force_preprocess=force_preprocess)
target_file, target_tc_model = preprocess(raw_target_file, target_language, force_preprocess=force_preprocess)
source_test_file, _model = preprocess(raw_source_test_file, source_language, force_preprocess=force_preprocess, pretrained_tc_model=source_tc_model)
target_test_file, _model = preprocess(raw_target_test_file, target_language, force_preprocess=force_preprocess, pretrained_tc_model=target_tc_model)
# Out:
# 100% 10691/10691 [00:02<00:00, 3651.92it/s]
# 10691it [00:04, 2156.18it/s]
# /content/drive/My Drive/TranslatorData/LegalData/legal_data_train_ru.txt_tc.model
# 10691it [00:03, 2897.84it/s]
# 100% 10691/10691 [00:03<00:00, 3561.40it/s]
# 10691it [00:05, 2086.47it/s]
# /content/drive/My Drive/TranslatorData/LegalData/legal_data_train_be.txt_tc.model
# 10691it [00:03, 2860.86it/s]
# 100% 1887/1887 [00:00<00:00, 3544.57it/s]
# /content/drive/My Drive/TranslatorData/LegalData/legal_data_train_ru.txt_tc.model
# 1887it [00:00, 2959.27it/s]
# 100% 1887/1887 [00:00<00:00, 3521.95it/s]
# /content/drive/My Drive/TranslatorData/LegalData/legal_data_train_be.txt_tc.model
# 1887it [00:00, 2726.94it/s]

# %%
# Train and test files should have the same length.
! wc -l "$raw_source_file"
! wc -l "$raw_target_file"
! wc -l "$raw_source_test_file"
! wc -l "$raw_target_test_file"
# Out:
# 10691 /content/drive/My Drive/TranslatorData/LegalData/legal_data_train_ru.txt
# 10691 /content/drive/My Drive/TranslatorData/LegalData/legal_data_train_be.txt
# 1887 /content/drive/My Drive/TranslatorData/LegalData/legal_data_test_ru.txt
# 1887 /content/drive/My Drive/TranslatorData/LegalData/legal_data_test_be.txt

# %%
# # Let's take a look what preprocessing did to the text.
# ! head "$raw_source_file"*
# ! head "$raw_target_file"*
# ! head "$raw_source_test_file"*
# ! head "$raw_target_test_file"*

# %%
import pandas as pd
import csv

def create_df(source_f, target_f, lowercase_first_letter=True):
   source = []
   target = []
   with open(source_f, "r") as source_f, open(target_f, "r") as target_f:
       for source_line, target_line in zip(source_f, target_f):
         if lowercase_first_letter:
            source_line = source_line[0].lower() + source_line[1:]
            target_line = target_line[0].lower() + target_line[1:]
         source.append(source_line.strip())
         target.append(target_line.strip())
  
   print(source[:5])
   df = pd.DataFrame(zip(source, target), columns=['source_sentence', 'target_sentence'])

   df_pp = df.drop_duplicates()
   df_pp = df_pp.sample(frac=1, random_state=42).reset_index(drop=True)
   return df_pp

def write_to_files(prefix, source_df):
  print(source_df['source_sentence'][:5])
  source_df['source_sentence'].to_csv(f"{prefix}.{source_language}", sep='\n', index=False, header=False)
  source_df['target_sentence'].to_csv(f"{prefix}.{target_language}", sep='\n', index=False, header=False)

train_dataset = create_df(source_file, target_file)
print(train_dataset.head())
test_df = create_df(source_test_file, target_test_file)

# We use 90% for train, rest for validation
num_train_patterns = int(len(train_dataset)*0.9)
train_df = train_dataset.head(num_train_patterns)
val_df = train_dataset.drop(train_df.index)

write_to_files("train", train_df)
write_to_files("dev", val_df)
write_to_files("test", test_df)
# Out:
# ['материально-техническое обеспечение национальных и сборных команд Республики Беларусь по видам спорта за счет средств республиканского бюджета осуществляется в порядке , установленном республиканским органом государственного управления , проводящим государственную политику в сфере физической культуры и спорта', 'при этом диспаша может оспариваться только на том основании , что она является явно неправильной', 'решение об отказе в предоставлении участка лесного фонда в аренду деревообрабатывающей организации для заготовки древесины может быть обжаловано в судебном порядке', 'граждане , зарегистрированные по месту пребывания , включаются в список только на участке для голосования по месту пребывания', 'счетная комиссия избирает из своего состава председателя , заместителя председателя и секретаря комиссии']
#                                      source_sentence                                    target_sentence
# 0  объектами отношений в области охраны и использ...  аб &apos; ектамі адносін у галіне аховы і выка...
# 1  обязательное страхование в области торгового м...  абавязковае страхаванне ў галіне гандлёвага ма...
# 2  применяемые средства индивидуальной защиты дол...  прымяняльныя сродкі індывідуальнай абароны пав...
# 3  обеспечение нормальных условий для выполнения ...  забеспячэнне нармальных умоў для выканання нор...
# 4  разубоживание – произошедшие в процессе добычи...  разубожванне – страта якасці карыснага выкапня...
# ['проверке и учету не подлежат подписи граждан , если в подписном листе отсутствует формулировка вопроса , предлагаемого на референдум , и ( или ) изложение существа предлагаемого решения ( законопроекта )', 'претензии , возникающие из перевозки внутренним водным транспортом грузов и буксировки судна , плота или иного плавучего объекта , предъявляются к перевозчику ( буксировщику ) в пункте назначения', 'в выборах , референдуме , голосовании об отзыве депутата', 'лоцманский', 'при отсутствии у лица , поступающего на работу , трудовой книжки в связи с ее утратой , повреждением или по иной причине по письменному заявлению этого лица ( с указанием причины отсутствия трудовой книжки ) в случаях , установленных законодательством , наниматель обязан завести трудовую книжку или оформить ее дубликат']
# 0    объектами отношений в области охраны и использ...
# 1    обязательное страхование в области торгового м...
# 2    применяемые средства индивидуальной защиты дол...
# 3    обеспечение нормальных условий для выполнения ...
# 4    разубоживание – произошедшие в процессе добычи...
# Name: source_sentence, dtype: object
# 9529    особенности создания дочерних банков , открыти...
# 9530    гражданское воздушное судно – воздушное судно ...
# 9531    аудит годовой бухгалтерской ( финансовой ) отч...
# 9532    поиск полезных ископаемых и ( или ) геотермаль...
# 9533    на имущество не являющегося индивидуальным пре...
# Name: source_sentence, dtype: object
# 0    временный перевод в связи с производственной н...
# 1    нахождение граждан на территории лесного фонда...
# 2    национальный банк устанавливает для юридически...
# 3    9 ) доля каждого из собственников в общей доле...
# 4    на республиканский референдум не могут выносит...
# Name: source_sentence, dtype: object

# %%
# ! head train.*
# ! head test.*

# %%
# %%capture
# installing cuda
if use_cuda:
    # !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
    # !sudo mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
    # !sudo apt-key adv --fetch-keys https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/7fa2af80.pub
    # !sudo add-apt-repository "deb http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/ /"
    # !sudo apt-get update
    # !sudo apt-get -y install cuda

# %%
# Install JoeyNMT
! cd joeynmt; pip3 install .

# %%
! cd joeynmt; python3 -m unittest
# Out:
# ................................s.......................
# ----------------------------------------------------------------------
# Ran 56 tests in 1.242s
#
# OK (skipped=1)

# %%
# Apply BPE splits to the train and test data.
# NB! We use vocabulary and BPE codes from out-of-domain training process
! subword-nmt apply-bpe -c "$bpe_codes_file" --vocabulary "${gdrive_path}/data/vocab.${src}" < train.$src > train.bpe.$src
! subword-nmt apply-bpe -c "$bpe_codes_file" --vocabulary "${gdrive_path}/data/vocab.${tgt}" < train.$tgt > train.bpe.$tgt

! subword-nmt apply-bpe -c "$bpe_codes_file" --vocabulary "${gdrive_path}/data/vocab.${src}" < dev.$src > dev.bpe.$src
! subword-nmt apply-bpe -c "$bpe_codes_file" --vocabulary "${gdrive_path}/data/vocab.${tgt}" < dev.$tgt > dev.bpe.$tgt
! subword-nmt apply-bpe -c "$bpe_codes_file" --vocabulary "${gdrive_path}/data/vocab.${src}" < test.$src > test.bpe.$src
! subword-nmt apply-bpe -c "$bpe_codes_file" --vocabulary "${gdrive_path}/data/vocab.${tgt}" < test.$tgt > test.bpe.$tgt

# %%
# Create directory, move everyone we care about to the correct location
! mkdir -p $data_path
! cp train.bpe* $data_path
! cp test.bpe* $data_path
! cp dev.bpe* $data_path
! cp "${gdrive_path}/data/vocab.txt" $data_path
! cp "${gdrive_path}/${config_name}" $data_path
! ls $data_path
# Out:
# dev.bpe.be  legal_data_config.yaml  test.bpe.ru   train.bpe.ru
# dev.bpe.ru  test.bpe.be		    train.bpe.be  vocab.txt

# %%
# Also move everything we care about to a mounted location in google drive (relevant if running in colab) at gdrive_path
! cp train.* "$gdrive_path/data"
! cp test.* "$gdrive_path/data"
! cp dev.* "$gdrive_path/data"
! ls "$gdrive_path"
! ls "$gdrive_path/data"
# Out:
# data  legal_data_config.yaml
# bpe.codes.5000	dev.bpe.ru  test.bpe.be  train.be      train.ru  vocab.txt
# dev.be		dev.ru	    test.bpe.ru  train.bpe.be  vocab.be
# dev.bpe.be	test.be     test.ru	 train.bpe.ru  vocab.ru

# %%
# Train the model
# You can press Ctrl-C to stop. And then run the next cell to save your checkpoints! 
# !cd joeynmt; python3 -m joeynmt train "/content/${data_path}/${config_name}"
# Out:
# 2021-02-23 08:39:15,132 - INFO - root - Hello! This is Joey-NMT (version 1.0).
# 2021-02-23 08:39:15,197 - INFO - joeynmt.data - loading training data...
# 2021-02-23 08:39:15,437 - INFO - joeynmt.data - building vocabulary...
# 2021-02-23 08:39:15,798 - INFO - joeynmt.data - loading dev data...
# 2021-02-23 08:39:15,820 - INFO - joeynmt.data - loading test data...
# 2021-02-23 08:39:15,863 - INFO - joeynmt.data - data loaded.
# 2021-02-23 08:39:16.352634: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-23 08:39:19,152 - INFO - joeynmt.training - Total params: 12424192
# 2021-02-23 08:39:21,024 - INFO - joeynmt.training - Loading model from /content/drive/My Drive/joey_experiments/ru-be-new_full/models/best.ckpt
# 2021-02-23 08:39:23,874 - INFO - joeynmt.training - Reset optimizer.
# 2021-02-23 08:39:23,875 - INFO - joeynmt.training - Reset scheduler.
# 2021-02-23 08:39:23,875 - INFO - joeynmt.training - Reset tracking of the best checkpoint.
# 2021-02-23 08:39:23,881 - INFO - joeynmt.helpers - cfg.name                           : rube_transformer_legal
# 2021-02-23 08:39:23,881 - INFO - joeynmt.helpers - cfg.data.src                       : ru
# 2021-02-23 08:39:23,881 - INFO - joeynmt.helpers - cfg.data.trg                       : be
# 2021-02-23 08:39:23,881 - INFO - joeynmt.helpers - cfg.data.train                     : data/rube/train.bpe
# 2021-02-23 08:39:23,881 - INFO - joeynmt.helpers - cfg.data.dev                       : data/rube/dev.bpe
# 2021-02-23 08:39:23,881 - INFO - joeynmt.helpers - cfg.data.test                      : data/rube/test.bpe
# 2021-02-23 08:39:23,881 - INFO - joeynmt.helpers - cfg.data.level                     : bpe
# 2021-02-23 08:39:23,881 - INFO - joeynmt.helpers - cfg.data.lowercase                 : False
# 2021-02-23 08:39:23,882 - INFO - joeynmt.helpers - cfg.data.max_sent_length           : 130
# 2021-02-23 08:39:23,882 - INFO - joeynmt.helpers - cfg.data.src_vocab                 : data/rube/vocab.txt
# 2021-02-23 08:39:23,882 - INFO - joeynmt.helpers - cfg.data.trg_vocab                 : data/rube/vocab.txt
# 2021-02-23 08:39:23,882 - INFO - joeynmt.helpers - cfg.testing.beam_size              : 5
# 2021-02-23 08:39:23,882 - INFO - joeynmt.helpers - cfg.testing.alpha                  : 1.0
# 2021-02-23 08:39:23,882 - INFO - joeynmt.helpers - cfg.testing.postproccess           : True
# 2021-02-23 08:39:23,882 - INFO - joeynmt.helpers - cfg.testing.sacrebleu.remove_whitespace : True
# 2021-02-23 08:39:23,882 - INFO - joeynmt.helpers - cfg.testing.sacrebleu.tokenize     : 13a
# 2021-02-23 08:39:23,882 - INFO - joeynmt.helpers - cfg.training.load_model            : /content/drive/My Drive/joey_experiments/ru-be-new_full/models/best.ckpt
# 2021-02-23 08:39:23,883 - INFO - joeynmt.helpers - cfg.training.reset_best_ckpt       : True
# 2021-02-23 08:39:23,883 - INFO - joeynmt.helpers - cfg.training.reset_scheduler       : True
# 2021-02-23 08:39:23,883 - INFO - joeynmt.helpers - cfg.training.reset_optimizer       : True
# 2021-02-23 08:39:23,883 - INFO - joeynmt.helpers - cfg.training.random_seed           : 42
# 2021-02-23 08:39:23,883 - INFO - joeynmt.helpers - cfg.training.optimizer             : adam
# 2021-02-23 08:39:23,883 - INFO - joeynmt.helpers - cfg.training.normalization         : tokens
# 2021-02-23 08:39:23,883 - INFO - joeynmt.helpers - cfg.training.adam_betas            : [0.9, 0.999]
# 2021-02-23 08:39:23,883 - INFO - joeynmt.helpers - cfg.training.scheduling            : plateau
# 2021-02-23 08:39:23,883 - INFO - joeynmt.helpers - cfg.training.patience              : 5
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.learning_rate_factor  : 0.5
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.learning_rate_warmup  : 1000
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.decrease_factor       : 0.7
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.loss                  : crossentropy
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.learning_rate         : 0.0003
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.learning_rate_min     : 1e-08
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.weight_decay          : 0.0
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.label_smoothing       : 0.1
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.batch_size            : 512
# 2021-02-23 08:39:23,884 - INFO - joeynmt.helpers - cfg.training.batch_type            : token
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.eval_batch_size       : 300
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.eval_batch_type       : token
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.batch_multiplier      : 1
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.early_stopping_metric : ppl
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.epochs                : 30
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.validation_freq       : 500
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.logging_freq          : 100
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.eval_metric           : bleu
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.model_dir             : models/rube_transformer_legal
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.overwrite             : True
# 2021-02-23 08:39:23,885 - INFO - joeynmt.helpers - cfg.training.shuffle               : True
# 2021-02-23 08:39:23,886 - INFO - joeynmt.helpers - cfg.training.use_cuda              : True
# 2021-02-23 08:39:23,886 - INFO - joeynmt.helpers - cfg.training.max_output_length     : 130
# 2021-02-23 08:39:23,886 - INFO - joeynmt.helpers - cfg.training.print_valid_sents     : [0, 1, 2, 3]
# 2021-02-23 08:39:23,886 - INFO - joeynmt.helpers - cfg.training.keep_last_ckpts       : 3
# 2021-02-23 08:39:23,886 - INFO - joeynmt.helpers - cfg.model.initializer              : xavier
# 2021-02-23 08:39:23,886 - INFO - joeynmt.helpers - cfg.model.bias_initializer         : zeros
# 2021-02-23 08:39:23,886 - INFO - joeynmt.helpers - cfg.model.init_gain                : 1.0
# 2021-02-23 08:39:23,886 - INFO - joeynmt.helpers - cfg.model.embed_initializer        : xavier
# 2021-02-23 08:39:23,886 - INFO - joeynmt.helpers - cfg.model.embed_init_gain          : 1.0
# 2021-02-23 08:39:23,887 - INFO - joeynmt.helpers - cfg.model.tied_embeddings          : True
# 2021-02-23 08:39:23,887 - INFO - joeynmt.helpers - cfg.model.tied_softmax             : True
# 2021-02-23 08:39:23,887 - INFO - joeynmt.helpers - cfg.model.encoder.type             : transformer
# 2021-02-23 08:39:23,887 - INFO - joeynmt.helpers - cfg.model.encoder.num_layers       : 6
# 2021-02-23 08:39:23,887 - INFO - joeynmt.helpers - cfg.model.encoder.num_heads        : 4
# 2021-02-23 08:39:23,887 - INFO - joeynmt.helpers - cfg.model.encoder.embeddings.embedding_dim : 256
# 2021-02-23 08:39:23,887 - INFO - joeynmt.helpers - cfg.model.encoder.embeddings.scale : True
# 2021-02-23 08:39:23,887 - INFO - joeynmt.helpers - cfg.model.encoder.embeddings.dropout : 0.2
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.encoder.hidden_size      : 256
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.encoder.ff_size          : 1024
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.encoder.dropout          : 0.3
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.decoder.type             : transformer
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.decoder.num_layers       : 6
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.decoder.num_heads        : 4
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.decoder.embeddings.embedding_dim : 256
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.decoder.embeddings.scale : True
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.decoder.embeddings.dropout : 0.2
# 2021-02-23 08:39:23,888 - INFO - joeynmt.helpers - cfg.model.decoder.hidden_size      : 256
# 2021-02-23 08:39:23,889 - INFO - joeynmt.helpers - cfg.model.decoder.ff_size          : 1024
# 2021-02-23 08:39:23,889 - INFO - joeynmt.helpers - cfg.model.decoder.dropout          : 0.3
# 2021-02-23 08:39:23,889 - INFO - joeynmt.helpers - Data set sizes:
# 	train 9298,
# 	valid 1059,
# 	test 1881
# 2021-02-23 08:39:23,889 - INFO - joeynmt.helpers - First training example:
# 	[SRC] объек@@ тами отношений в области ох@@ раны и использо@@ вания вод являются :
# 	[TRG] аб &apos; ек@@ тамі адносі@@ н у галіне аховы і выкарыстан@@ ня вод з &apos; яўляюцца :
# 2021-02-23 08:39:23,889 - INFO - joeynmt.helpers - First 10 words (src): (0) <unk> (1) <pad> (2) <s> (3) </s> (4) , (5) . (6) на (7) в (8) — (9) и
# 2021-02-23 08:39:23,889 - INFO - joeynmt.helpers - First 10 words (trg): (0) <unk> (1) <pad> (2) <s> (3) </s> (4) , (5) . (6) на (7) в (8) — (9) и
# 2021-02-23 08:39:23,889 - INFO - joeynmt.helpers - Number of Src words (types): 5328
# 2021-02-23 08:39:23,890 - INFO - joeynmt.helpers - Number of Trg words (types): 5328
# 2021-02-23 08:39:23,890 - INFO - joeynmt.training - Model(
# 	encoder=TransformerEncoder(num_layers=6, num_heads=4),
# 	decoder=TransformerDecoder(num_layers=6, num_heads=4),
# 	src_embed=Embeddings(embedding_dim=256, vocab_size=5328),
# 	trg_embed=Embeddings(embedding_dim=256, vocab_size=5328))
# 2021-02-23 08:39:23,896 - INFO - joeynmt.training - Train stats:
# 	device: cuda
# 	n_gpu: 1
# 	16-bits training: False
# 	gradient accumulation: 1
# 	batch size per device: 512
# 	total batch size (w. parallel & accumulation): 512
# 2021-02-23 08:39:23,896 - INFO - joeynmt.training - EPOCH 1
# 2021-02-23 08:39:36,315 - INFO - joeynmt.training - Epoch   1, Step:    44100, Batch Loss:     0.445826, Tokens per Sec:     3377, Lr: 0.000300
# 2021-02-23 08:39:48,692 - INFO - joeynmt.training - Epoch   1, Step:    44200, Batch Loss:     0.493008, Tokens per Sec:     3372, Lr: 0.000300
# 2021-02-23 08:40:00,900 - INFO - joeynmt.training - Epoch   1, Step:    44300, Batch Loss:     0.457520, Tokens per Sec:     3411, Lr: 0.000300
# 2021-02-23 08:40:13,061 - INFO - joeynmt.training - Epoch   1, Step:    44400, Batch Loss:     0.301072, Tokens per Sec:     3420, Lr: 0.000300
# 2021-02-23 08:40:25,289 - INFO - joeynmt.training - Epoch   1, Step:    44500, Batch Loss:     1.180985, Tokens per Sec:     3409, Lr: 0.000300
# 2021-02-23 08:46:10,797 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2021-02-23 08:46:10,797 - INFO - joeynmt.training - Saving new checkpoint.
# 2021-02-23 08:46:11,270 - INFO - joeynmt.training - Example #0
# 2021-02-23 08:46:11,271 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 08:46:11,271 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 08:46:11,271 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 08:46:11,271 - INFO - joeynmt.training - Example #1
# 2021-02-23 08:46:11,271 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 08:46:11,271 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 08:46:11,272 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якая выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 08:46:11,272 - INFO - joeynmt.training - Example #2
# 2021-02-23 08:46:11,272 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 08:46:11,272 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 08:46:11,272 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 08:46:11,272 - INFO - joeynmt.training - Example #3
# 2021-02-23 08:46:11,273 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 08:46:11,273 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 08:46:11,273 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 08:46:11,273 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step    44500: bleu:  85.62, loss: 18254.3398, ppl:   1.4605, duration: 345.9831s
# 2021-02-23 08:46:23,612 - INFO - joeynmt.training - Epoch   1, Step:    44600, Batch Loss:     0.334003, Tokens per Sec:     3376, Lr: 0.000300
# 2021-02-23 08:46:35,875 - INFO - joeynmt.training - Epoch   1, Step:    44700, Batch Loss:     0.328235, Tokens per Sec:     3431, Lr: 0.000300
# 2021-02-23 08:46:48,107 - INFO - joeynmt.training - Epoch   1, Step:    44800, Batch Loss:     0.444832, Tokens per Sec:     3378, Lr: 0.000300
# 2021-02-23 08:47:00,370 - INFO - joeynmt.training - Epoch   1, Step:    44900, Batch Loss:     0.397178, Tokens per Sec:     3426, Lr: 0.000300
# 2021-02-23 08:47:05,901 - INFO - joeynmt.training - Epoch   1: total training loss 369.69
# 2021-02-23 08:47:05,901 - INFO - joeynmt.training - EPOCH 2
# 2021-02-23 08:47:12,660 - INFO - joeynmt.training - Epoch   2, Step:    45000, Batch Loss:     0.276640, Tokens per Sec:     3410, Lr: 0.000300
# 2021-02-23 08:52:59,643 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2021-02-23 08:52:59,643 - INFO - joeynmt.training - Saving new checkpoint.
# 2021-02-23 08:53:00,122 - INFO - joeynmt.training - Example #0
# 2021-02-23 08:53:00,122 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 08:53:00,122 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 08:53:00,122 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 08:53:00,122 - INFO - joeynmt.training - Example #1
# 2021-02-23 08:53:00,123 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 08:53:00,123 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 08:53:00,123 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 08:53:00,123 - INFO - joeynmt.training - Example #2
# 2021-02-23 08:53:00,123 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 08:53:00,123 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 08:53:00,123 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 08:53:00,124 - INFO - joeynmt.training - Example #3
# 2021-02-23 08:53:00,124 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 08:53:00,124 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 08:53:00,124 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 08:53:00,124 - INFO - joeynmt.training - Validation result (greedy) at epoch   2, step    45000: bleu:  87.45, loss: 16983.9004, ppl:   1.4225, duration: 347.4638s
# 2021-02-23 08:53:12,464 - INFO - joeynmt.training - Epoch   2, Step:    45100, Batch Loss:     0.230325, Tokens per Sec:     3363, Lr: 0.000300
# 2021-02-23 08:53:24,735 - INFO - joeynmt.training - Epoch   2, Step:    45200, Batch Loss:     0.403228, Tokens per Sec:     3407, Lr: 0.000300
# 2021-02-23 08:53:37,057 - INFO - joeynmt.training - Epoch   2, Step:    45300, Batch Loss:     0.196816, Tokens per Sec:     3385, Lr: 0.000300
# 2021-02-23 08:53:49,420 - INFO - joeynmt.training - Epoch   2, Step:    45400, Batch Loss:     0.316824, Tokens per Sec:     3382, Lr: 0.000300
# 2021-02-23 08:54:01,692 - INFO - joeynmt.training - Epoch   2, Step:    45500, Batch Loss:     0.249094, Tokens per Sec:     3320, Lr: 0.000300
# 2021-02-23 08:59:48,884 - INFO - joeynmt.training - Example #0
# 2021-02-23 08:59:48,885 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 08:59:48,885 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 08:59:48,885 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 08:59:48,885 - INFO - joeynmt.training - Example #1
# 2021-02-23 08:59:48,885 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 08:59:48,885 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 08:59:48,885 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 08:59:48,886 - INFO - joeynmt.training - Example #2
# 2021-02-23 08:59:48,886 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 08:59:48,886 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 08:59:48,886 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 08:59:48,886 - INFO - joeynmt.training - Example #3
# 2021-02-23 08:59:48,886 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 08:59:48,886 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 08:59:48,887 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 08:59:48,887 - INFO - joeynmt.training - Validation result (greedy) at epoch   2, step    45500: bleu:  87.54, loss: 17144.7500, ppl:   1.4272, duration: 347.1941s
# 2021-02-23 09:00:01,085 - INFO - joeynmt.training - Epoch   2, Step:    45600, Batch Loss:     0.318359, Tokens per Sec:     3411, Lr: 0.000300
# 2021-02-23 09:00:13,330 - INFO - joeynmt.training - Epoch   2, Step:    45700, Batch Loss:     0.282939, Tokens per Sec:     3391, Lr: 0.000300
# 2021-02-23 09:00:25,591 - INFO - joeynmt.training - Epoch   2, Step:    45800, Batch Loss:     0.376687, Tokens per Sec:     3367, Lr: 0.000300
# 2021-02-23 09:00:37,054 - INFO - joeynmt.training - Epoch   2: total training loss 294.66
# 2021-02-23 09:00:37,054 - INFO - joeynmt.training - EPOCH 3
# 2021-02-23 09:00:37,953 - INFO - joeynmt.training - Epoch   3, Step:    45900, Batch Loss:     0.274557, Tokens per Sec:     3279, Lr: 0.000300
# 2021-02-23 09:00:50,199 - INFO - joeynmt.training - Epoch   3, Step:    46000, Batch Loss:     0.309790, Tokens per Sec:     3409, Lr: 0.000300
# 2021-02-23 09:06:36,953 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2021-02-23 09:06:36,954 - INFO - joeynmt.training - Saving new checkpoint.
# 2021-02-23 09:06:37,431 - INFO - joeynmt.training - Example #0
# 2021-02-23 09:06:37,431 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 09:06:37,431 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:06:37,431 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:06:37,431 - INFO - joeynmt.training - Example #1
# 2021-02-23 09:06:37,432 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 09:06:37,432 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:06:37,432 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:06:37,432 - INFO - joeynmt.training - Example #2
# 2021-02-23 09:06:37,432 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 09:06:37,432 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:06:37,433 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:06:37,433 - INFO - joeynmt.training - Example #3
# 2021-02-23 09:06:37,433 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 09:06:37,433 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:06:37,433 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:06:37,433 - INFO - joeynmt.training - Validation result (greedy) at epoch   3, step    46000: bleu:  88.10, loss: 16901.6133, ppl:   1.4201, duration: 347.2331s
# 2021-02-23 09:06:49,762 - INFO - joeynmt.training - Epoch   3, Step:    46100, Batch Loss:     0.198369, Tokens per Sec:     3355, Lr: 0.000300
# 2021-02-23 09:07:02,140 - INFO - joeynmt.training - Epoch   3, Step:    46200, Batch Loss:     0.291482, Tokens per Sec:     3388, Lr: 0.000300
# 2021-02-23 09:07:14,473 - INFO - joeynmt.training - Epoch   3, Step:    46300, Batch Loss:     0.274590, Tokens per Sec:     3359, Lr: 0.000300
# 2021-02-23 09:07:26,849 - INFO - joeynmt.training - Epoch   3, Step:    46400, Batch Loss:     0.225546, Tokens per Sec:     3349, Lr: 0.000300
# 2021-02-23 09:07:39,232 - INFO - joeynmt.training - Epoch   3, Step:    46500, Batch Loss:     0.431835, Tokens per Sec:     3393, Lr: 0.000300
# 2021-02-23 09:13:26,801 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2021-02-23 09:13:26,801 - INFO - joeynmt.training - Saving new checkpoint.
# 2021-02-23 09:13:27,274 - INFO - joeynmt.training - Example #0
# 2021-02-23 09:13:27,275 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 09:13:27,275 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:13:27,276 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:13:27,276 - INFO - joeynmt.training - Example #1
# 2021-02-23 09:13:27,276 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 09:13:27,276 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:13:27,276 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:13:27,276 - INFO - joeynmt.training - Example #2
# 2021-02-23 09:13:27,277 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 09:13:27,277 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:13:27,277 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:13:27,277 - INFO - joeynmt.training - Example #3
# 2021-02-23 09:13:27,277 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 09:13:27,277 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:13:27,278 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:13:27,278 - INFO - joeynmt.training - Validation result (greedy) at epoch   3, step    46500: bleu:  88.36, loss: 16120.4199, ppl:   1.3972, duration: 348.0453s
# 2021-02-23 09:13:39,642 - INFO - joeynmt.training - Epoch   3, Step:    46600, Batch Loss:     0.362570, Tokens per Sec:     3391, Lr: 0.000300
# 2021-02-23 09:13:51,890 - INFO - joeynmt.training - Epoch   3, Step:    46700, Batch Loss:     0.316343, Tokens per Sec:     3407, Lr: 0.000300
# 2021-02-23 09:14:04,237 - INFO - joeynmt.training - Epoch   3, Step:    46800, Batch Loss:     0.303368, Tokens per Sec:     3412, Lr: 0.000300
# 2021-02-23 09:14:08,767 - INFO - joeynmt.training - Epoch   3: total training loss 264.66
# 2021-02-23 09:14:08,767 - INFO - joeynmt.training - EPOCH 4
# 2021-02-23 09:14:16,491 - INFO - joeynmt.training - Epoch   4, Step:    46900, Batch Loss:     0.329602, Tokens per Sec:     3374, Lr: 0.000300
# 2021-02-23 09:14:28,740 - INFO - joeynmt.training - Epoch   4, Step:    47000, Batch Loss:     0.238634, Tokens per Sec:     3377, Lr: 0.000300
# 2021-02-23 09:20:15,211 - INFO - joeynmt.training - Example #0
# 2021-02-23 09:20:15,211 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 09:20:15,211 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:20:15,212 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:20:15,212 - INFO - joeynmt.training - Example #1
# 2021-02-23 09:20:15,212 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 09:20:15,212 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:20:15,212 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:20:15,212 - INFO - joeynmt.training - Example #2
# 2021-02-23 09:20:15,213 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 09:20:15,213 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:20:15,213 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:20:15,213 - INFO - joeynmt.training - Example #3
# 2021-02-23 09:20:15,213 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 09:20:15,213 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:20:15,213 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:20:15,214 - INFO - joeynmt.training - Validation result (greedy) at epoch   4, step    47000: bleu:  88.75, loss: 16820.8066, ppl:   1.4177, duration: 346.4732s
# 2021-02-23 09:20:27,541 - INFO - joeynmt.training - Epoch   4, Step:    47100, Batch Loss:     0.199510, Tokens per Sec:     3408, Lr: 0.000300
# 2021-02-23 09:20:39,793 - INFO - joeynmt.training - Epoch   4, Step:    47200, Batch Loss:     0.273233, Tokens per Sec:     3396, Lr: 0.000300
# 2021-02-23 09:20:52,034 - INFO - joeynmt.training - Epoch   4, Step:    47300, Batch Loss:     0.388240, Tokens per Sec:     3425, Lr: 0.000300
# 2021-02-23 09:21:04,291 - INFO - joeynmt.training - Epoch   4, Step:    47400, Batch Loss:     0.247419, Tokens per Sec:     3372, Lr: 0.000300
# 2021-02-23 09:21:16,605 - INFO - joeynmt.training - Epoch   4, Step:    47500, Batch Loss:     0.285229, Tokens per Sec:     3396, Lr: 0.000300
# 2021-02-23 09:27:04,031 - INFO - joeynmt.training - Example #0
# 2021-02-23 09:27:04,032 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 09:27:04,032 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:27:04,032 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:27:04,032 - INFO - joeynmt.training - Example #1
# 2021-02-23 09:27:04,032 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 09:27:04,032 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:27:04,032 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:27:04,032 - INFO - joeynmt.training - Example #2
# 2021-02-23 09:27:04,033 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 09:27:04,033 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:27:04,033 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:27:04,033 - INFO - joeynmt.training - Example #3
# 2021-02-23 09:27:04,033 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 09:27:04,033 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:27:04,034 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:27:04,034 - INFO - joeynmt.training - Validation result (greedy) at epoch   4, step    47500: bleu:  88.97, loss: 16140.1787, ppl:   1.3978, duration: 347.4285s
# 2021-02-23 09:27:16,384 - INFO - joeynmt.training - Epoch   4, Step:    47600, Batch Loss:     0.209296, Tokens per Sec:     3339, Lr: 0.000300
# 2021-02-23 09:27:28,669 - INFO - joeynmt.training - Epoch   4, Step:    47700, Batch Loss:     0.190131, Tokens per Sec:     3341, Lr: 0.000300
# 2021-02-23 09:27:39,084 - INFO - joeynmt.training - Epoch   4: total training loss 249.29
# 2021-02-23 09:27:39,084 - INFO - joeynmt.training - EPOCH 5
# 2021-02-23 09:27:41,093 - INFO - joeynmt.training - Epoch   5, Step:    47800, Batch Loss:     0.220856, Tokens per Sec:     3294, Lr: 0.000300
# 2021-02-23 09:27:53,477 - INFO - joeynmt.training - Epoch   5, Step:    47900, Batch Loss:     0.190449, Tokens per Sec:     3409, Lr: 0.000300
# 2021-02-23 09:28:05,776 - INFO - joeynmt.training - Epoch   5, Step:    48000, Batch Loss:     0.230391, Tokens per Sec:     3350, Lr: 0.000300
# 2021-02-23 09:33:51,609 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2021-02-23 09:33:51,609 - INFO - joeynmt.training - Saving new checkpoint.
# 2021-02-23 09:33:52,078 - INFO - joeynmt.training - Example #0
# 2021-02-23 09:33:52,079 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 09:33:52,079 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:33:52,079 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:33:52,079 - INFO - joeynmt.training - Example #1
# 2021-02-23 09:33:52,080 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 09:33:52,080 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:33:52,080 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:33:52,080 - INFO - joeynmt.training - Example #2
# 2021-02-23 09:33:52,080 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 09:33:52,080 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:33:52,080 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:33:52,081 - INFO - joeynmt.training - Example #3
# 2021-02-23 09:33:52,081 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 09:33:52,081 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:33:52,081 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:33:52,081 - INFO - joeynmt.training - Validation result (greedy) at epoch   5, step    48000: bleu:  89.18, loss: 16000.2871, ppl:   1.3937, duration: 346.3045s
# 2021-02-23 09:34:04,388 - INFO - joeynmt.training - Epoch   5, Step:    48100, Batch Loss:     0.244810, Tokens per Sec:     3376, Lr: 0.000300
# 2021-02-23 09:34:16,742 - INFO - joeynmt.training - Epoch   5, Step:    48200, Batch Loss:     0.192606, Tokens per Sec:     3307, Lr: 0.000300
# 2021-02-23 09:34:29,066 - INFO - joeynmt.training - Epoch   5, Step:    48300, Batch Loss:     0.263868, Tokens per Sec:     3336, Lr: 0.000300
# 2021-02-23 09:34:41,364 - INFO - joeynmt.training - Epoch   5, Step:    48400, Batch Loss:     0.450479, Tokens per Sec:     3398, Lr: 0.000300
# 2021-02-23 09:34:53,641 - INFO - joeynmt.training - Epoch   5, Step:    48500, Batch Loss:     0.171651, Tokens per Sec:     3398, Lr: 0.000300
# 2021-02-23 09:40:40,154 - INFO - joeynmt.training - Example #0
# 2021-02-23 09:40:40,155 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 09:40:40,155 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:40:40,155 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 09:40:40,155 - INFO - joeynmt.training - Example #1
# 2021-02-23 09:40:40,155 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 09:40:40,155 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:40:40,155 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 09:40:40,156 - INFO - joeynmt.training - Example #2
# 2021-02-23 09:40:40,156 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 09:40:40,156 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:40:40,156 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 09:40:40,156 - INFO - joeynmt.training - Example #3
# 2021-02-23 09:40:40,156 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 09:40:40,156 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:40:40,157 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 09:40:40,157 - INFO - joeynmt.training - Validation result (greedy) at epoch   5, step    48500: bleu:  89.14, loss: 16157.4258, ppl:   1.3983, duration: 346.5150s
# 2021-02-23 09:40:52,493 - INFO - joeynmt.training - Epoch   5, Step:    48600, Batch Loss:     0.276704, Tokens per Sec:     3447, Lr: 0.000300
# 2021-02-23 09:41:04,757 - INFO - joeynmt.training - Epoch   5, Step:    48700, Batch Loss:     0.239150, Tokens per Sec:     3378, Lr: 0.000300
# 2021-02-23 09:41:08,736 - INFO - joeynmt.training - Epoch   5: total training loss 235.83
# 2021-02-23 09:41:08,736 - INFO - joeynmt.training - EPOCH 6
# 2021-02-23 09:41:17,107 - INFO - joeynmt.training - Epoch   6, Step:    48800, Batch Loss:     0.290411, Tokens per Sec:     3382, Lr: 0.000300
# 2021-02-23 09:41:29,332 - INFO - joeynmt.training - Epoch   6, Step:    48900, Batch Loss:     0.270563, Tokens per Sec:     3376, Lr: 0.000300
# 2021-02-23 09:41:41,605 - INFO - joeynmt.training - Epoch   6, Step:    49000, Batch Loss:     0.221428, Tokens per Sec:     3365, Lr: 0.000300
# 2021-02-23 09:47:29,410 - INFO - joeynmt.training - Example #0
# ...
# 2021-02-23 10:35:32,872 - INFO - joeynmt.training - Epoch  10, Step:    52600, Batch Loss:     0.233871, Tokens per Sec:     3321, Lr: 0.000300
# 2021-02-23 10:35:45,253 - INFO - joeynmt.training - Epoch  10, Step:    52700, Batch Loss:     0.177216, Tokens per Sec:     3379, Lr: 0.000300
# 2021-02-23 10:35:57,700 - INFO - joeynmt.training - Epoch  10, Step:    52800, Batch Loss:     0.224045, Tokens per Sec:     3312, Lr: 0.000300
# 2021-02-23 10:36:10,137 - INFO - joeynmt.training - Epoch  10, Step:    52900, Batch Loss:     0.205607, Tokens per Sec:     3407, Lr: 0.000300
# 2021-02-23 10:36:22,479 - INFO - joeynmt.training - Epoch  10, Step:    53000, Batch Loss:     0.141587, Tokens per Sec:     3377, Lr: 0.000300
# 2021-02-23 10:42:08,763 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2021-02-23 10:42:08,763 - INFO - joeynmt.training - Saving new checkpoint.
# 2021-02-23 10:42:09,226 - INFO - joeynmt.training - Example #0
# 2021-02-23 10:42:09,226 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 10:42:09,226 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 10:42:09,227 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 10:42:09,227 - INFO - joeynmt.training - Example #1
# 2021-02-23 10:42:09,227 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 10:42:09,227 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 10:42:09,227 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 10:42:09,227 - INFO - joeynmt.training - Example #2
# 2021-02-23 10:42:09,228 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 10:42:09,228 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 10:42:09,228 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 10:42:09,228 - INFO - joeynmt.training - Example #3
# 2021-02-23 10:42:09,228 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 10:42:09,228 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 10:42:09,228 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 10:42:09,228 - INFO - joeynmt.training - Validation result (greedy) at epoch  10, step    53000: bleu:  89.65, loss: 15152.8047, ppl:   1.3695, duration: 346.7488s
# 2021-02-23 10:42:21,532 - INFO - joeynmt.training - Epoch  10, Step:    53100, Batch Loss:     0.137825, Tokens per Sec:     3379, Lr: 0.000300
# 2021-02-23 10:42:33,760 - INFO - joeynmt.training - Epoch  10, Step:    53200, Batch Loss:     0.201502, Tokens per Sec:     3413, Lr: 0.000300
# 2021-02-23 10:42:46,012 - INFO - joeynmt.training - Epoch  10, Step:    53300, Batch Loss:     0.212910, Tokens per Sec:     3428, Lr: 0.000300
# 2021-02-23 10:42:58,231 - INFO - joeynmt.training - Epoch  10, Step:    53400, Batch Loss:     0.180232, Tokens per Sec:     3370, Lr: 0.000300
# 2021-02-23 10:43:05,480 - INFO - joeynmt.training - Epoch  10: total training loss 202.82
# 2021-02-23 10:43:05,480 - INFO - joeynmt.training - EPOCH 11
# 2021-02-23 10:43:10,514 - INFO - joeynmt.training - Epoch  11, Step:    53500, Batch Loss:     0.189775, Tokens per Sec:     3394, Lr: 0.000300
# 2021-02-23 10:48:59,874 - INFO - joeynmt.training - Example #0
# 2021-02-23 10:48:59,875 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 10:48:59,875 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 10:48:59,875 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 10:48:59,875 - INFO - joeynmt.training - Example #1
# 2021-02-23 10:48:59,876 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 10:48:59,876 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 10:48:59,876 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 10:48:59,876 - INFO - joeynmt.training - Example #2
# 2021-02-23 10:48:59,876 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 10:48:59,876 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 10:48:59,876 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 10:48:59,877 - INFO - joeynmt.training - Example #3
# 2021-02-23 10:48:59,877 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 10:48:59,877 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 10:48:59,877 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 10:48:59,877 - INFO - joeynmt.training - Validation result (greedy) at epoch  11, step    53500: bleu:  89.34, loss: 15428.1621, ppl:   1.3773, duration: 349.3622s
# 2021-02-23 10:49:12,254 - INFO - joeynmt.training - Epoch  11, Step:    53600, Batch Loss:     0.227729, Tokens per Sec:     3276, Lr: 0.000300
# 2021-02-23 10:49:24,598 - INFO - joeynmt.training - Epoch  11, Step:    53700, Batch Loss:     0.210937, Tokens per Sec:     3355, Lr: 0.000300
# 2021-02-23 10:49:36,938 - INFO - joeynmt.training - Epoch  11, Step:    53800, Batch Loss:     0.114459, Tokens per Sec:     3372, Lr: 0.000300
# 2021-02-23 10:49:49,299 - INFO - joeynmt.training - Epoch  11, Step:    53900, Batch Loss:     0.174323, Tokens per Sec:     3431, Lr: 0.000300
# 2021-02-23 10:50:01,612 - INFO - joeynmt.training - Epoch  11, Step:    54000, Batch Loss:     0.232760, Tokens per Sec:     3365, Lr: 0.000300
# 2021-02-23 10:55:48,146 - INFO - joeynmt.training - Example #0
# 2021-02-23 10:55:48,147 - INFO - joeynmt.training - 	Source:     особенности создания дочерних банков , открытия филиалов и представительств банков-резидентов за пределами республики беларусь
# 2021-02-23 10:55:48,147 - INFO - joeynmt.training - 	Reference:  асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 10:55:48,147 - INFO - joeynmt.training - 	Hypothesis: асаблівасці стварэння даччыных банкаў , адкрыцця філіялаў і прадстаўніцтваў банкаў-рэзідэнтаў за межамі рэспублікі беларусь
# 2021-02-23 10:55:48,147 - INFO - joeynmt.training - Example #1
# 2021-02-23 10:55:48,147 - INFO - joeynmt.training - 	Source:     гражданское воздушное судно – воздушное судно , используемое в гражданской авиации и зарегистрированное в Государственном реестре гражданских воздушных судов Республики Беларусь
# 2021-02-23 10:55:48,148 - INFO - joeynmt.training - 	Reference:  грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістравана ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 10:55:48,148 - INFO - joeynmt.training - 	Hypothesis: грамадзянскае паветранае судна – паветранае судна , якое выкарыстоўваецца ў грамадзянскай авіяцыі і зарэгістраванае ў Дзяржаўным рэестры грамадзянскіх паветраных суднаў Рэспублікі Беларусь
# 2021-02-23 10:55:48,148 - INFO - joeynmt.training - Example #2
# 2021-02-23 10:55:48,148 - INFO - joeynmt.training - 	Source:     аудит годовой бухгалтерской ( финансовой ) отчетности Национального банка и годовой консолидированной финансовой отчетности Национального банка в соответствии с международными стандартами финансовой отчетности проводится в порядке , установленном законодательством Республики Беларусь
# 2021-02-23 10:55:48,148 - INFO - joeynmt.training - 	Reference:  аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 10:55:48,148 - INFO - joeynmt.training - 	Hypothesis: аўдыт гадавой бухгалтарскай ( фінансавай ) справаздачнасці Нацыянальнага банка і гадавой кансалідаванай фінансавай справаздачнасці Нацыянальнага банка ў адпаведнасці з міжнароднымі стандартамі фінансавай справаздачнасці праводзіцца ў парадку , устаноўленым заканадаўствам Рэспублікі Беларусь
# 2021-02-23 10:55:48,148 - INFO - joeynmt.training - Example #3
# 2021-02-23 10:55:48,149 - INFO - joeynmt.training - 	Source:     поиск полезных ископаемых и ( или ) геотермальных ресурсов недр и оценка месторождения
# 2021-02-23 10:55:48,149 - INFO - joeynmt.training - 	Reference:  пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 10:55:48,149 - INFO - joeynmt.training - 	Hypothesis: пошук карысных выкапняў і ( або ) геатэрмальных рэсурсаў нетраў і ацэнка радовішча
# 2021-02-23 10:55:48,149 - INFO - joeynmt.training - Validation result (greedy) at epoch  11, step    54000: bleu:  89.44, loss: 15537.9902, ppl:   1.3804, duration: 346.5367s
# 2021-02-23 10:56:00,522 - INFO - joeynmt.training - Epoch  11, Step:    54100, Batch Loss:     0.300487, Tokens per Sec:     3375, Lr: 0.000300
# 2021-02-23 10:56:12,850 - INFO - joeynmt.training - Epoch  11, Step:    54200, Batch Loss:     0.253871, Tokens per Sec:     3383, Lr: 0.000300
# 2021-02-23 10:56:25,160 - INFO - joeynmt.training - Epoch  11, Step:    54300, Batch Loss:     0.351321, Tokens per Sec:     3385, Lr: 0.000300
# 2021-02-23 10:56:37,460 - INFO - joeynmt.training - Epoch  11, Step:    54400, Batch Loss:     0.186866, Tokens per Sec:     3389, Lr: 0.000300
# 2021-02-23 10:56:38,314 - INFO - joeynmt.training - Epoch  11: total training loss 201.38
# 2021-02-23 10:56:38,314 - INFO - joeynmt.training - EPOCH 12
# 2021-02-23 10:56:49,854 - INFO - joeynmt.training - Epoch  12, Step:    54500, Batch Loss:     0.179691, Tokens per Sec:     3332, Lr: 0.000300
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/content/joeynmt/joeynmt/__main__.py", line 41, in <module>
#     main()
#   File "/content/joeynmt/joeynmt/__main__.py", line 29, in main
#     train(cfg_file=args.config_path)
#   File "/content/joeynmt/joeynmt/training.py", line 744, in train
#     trainer.train_and_validate(train_data=train_data, valid_data=dev_data)
#   File "/content/joeynmt/joeynmt/training.py", line 428, in train_and_validate
#     valid_duration = self._validate(valid_data, epoch_no)
#   File "/content/joeynmt/joeynmt/training.py", line 517, in _validate
#     n_gpu=self.n_gpu
#   File "/content/joeynmt/joeynmt/prediction.py", line 121, in validate_on_data
#     beam_alpha=beam_alpha, max_output_length=max_output_length)
#   File "/content/joeynmt/joeynmt/search.py", line 445, in run_batch
#     encoder_hidden=encoder_hidden)
#   File "/content/joeynmt/joeynmt/search.py", line 39, in greedy
#     src_mask, max_output_length, model, encoder_output, encoder_hidden)
#   File "/content/joeynmt/joeynmt/search.py", line 146, in transformer_greedy
#     trg_mask=trg_mask
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/joeynmt/joeynmt/model.py", line 117, in forward
#     trg_mask=kwargs.get("trg_mask", None))
#   File "/content/joeynmt/joeynmt/model.py", line 186, in _decode
#     trg_mask=trg_mask)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/joeynmt/joeynmt/decoders.py", line 518, in forward
#     src_mask=src_mask, trg_mask=trg_mask)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/joeynmt/joeynmt/transformer_layers.py", line 264, in forward
#     h1 = self.trg_trg_att(x_norm, x_norm, x_norm, mask=trg_mask)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/joeynmt/joeynmt/transformer_layers.py", line 56, in forward
#     v = self.v_layer(v)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/linear.py", line 93, in forward
#     return F.linear(input, self.weight, self.bias)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/functional.py", line 1688, in linear
#     if input.dim() == 2 and bias is not None:
# KeyboardInterrupt

# %%
# # Copy the created models from the notebook storage to google drive for persistant storage 
# !mkdir -p "$gdrive_path/models/" && cp -r joeynmt/models/${src}${tgt}_transformer_legal/* "$gdrive_path/models/"
